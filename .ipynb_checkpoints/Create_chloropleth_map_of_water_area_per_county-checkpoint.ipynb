# %%
  # %matplotlib inline
import geopandas as gpd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from cartopy.feature import ShapelyFeature
import cartopy.crs as ccrs
import matplotlib.patches as mpatches
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px

# %%
# generate matplotlib handles to create a legend of the features we put in our map.
def generate_handles(labels, colors, edge='k', alpha=1):
    lc = len(colors)  # get the length of the color list
    handles = []
    for i in range(len(labels)):
        handles.append(mpatches.Rectangle((0, 0), 1, 1, facecolor=colors[i % lc], edgecolor=edge, alpha=alpha))
    return handles


plt.ion()

# %%
# load the outline of Northern Ireland and Ireland
outline = gpd.read_file('data_files/Simplified_Shapes/Ireland.shp')
outline = outline.to_crs(epsg=2158)


#load datasets for display on map
water = gpd.read_file('data_files/Files_for_analysis/water_per_county.shp')
water = water.to_crs(epsg=2158)

counties = gpd.read_file('data_files/Files_for_analysis/Ire_Counties.shp')
counties = counties.to_crs(epsg=2158)

# %%
water
# Out:
#     FID_   osm_id  code  fclass  population                name  COUNT  \
# 0      0   334898  1041  county         0.0     County Limerick   12.0
# 1      7   283679  1041  county         0.0        County Cavan  326.0
# 2      3   335445  1041  county         0.0     County Longford   31.0
# 3      6   334372  1041  county         0.0    County Tipperary   35.0
# 4     10   332631  1041  county         0.0         County Cork  186.0
# 5      2   335442  1041  county         0.0       County Offaly   14.0
# 6      9   284368  1041  county         0.0      County Leitrim  183.0
# 7     13  1118085  1041  county         0.0    County Fermanagh  232.0
# 8      5   283426  1041  county         0.0    County Waterford   27.0
# 9     12   285915  1041  county         0.0        County Laois    8.0
# 10    16   285981  1041  county         0.0      County Wexford   13.0
# 11     8   335330  1041  county         0.0        County Sligo  126.0
# 12    11   285980  1041  county         0.0     County Kilkenny   13.0
# 13    19   335444  1041  county         0.0       County Galway  595.0
# 14    22   282818  1041  county         0.0        County Meath   32.0
# 15    18   334885  1041  county         0.0        County Clare  273.0
# 16    14   283647  1041  county         0.0     County Monaghan  269.0
# 17    25   282800  1041  county         0.0       County Dublin   36.0
# 18    17  1117773  1041  county         0.0       County Tyrone  149.0
# 19    21  1763195  1041  county         0.0        County Louth    9.0
# 20    24   285833  1041  county         0.0      County Kildare   12.0
# 21    20   335446  1041  county         0.0    County Westmeath   55.0
# 22    28  1119534  1041  county         0.0       County Antrim   65.0
# 23    31   283732  1041  county         0.0      County Donegal  651.0
# 24    23   282760  1041  county         0.0      County Wicklow   30.0
# 25    27  1119535  1041  county         0.0       County Armagh   76.0
# 26    30   332622  1041  county         0.0        County Kerry  145.0
# 27    26  1119533  1041  county         0.0         County Down   90.0
# 28    29  4085175  1041  county         0.0         County Mayo  420.0
# 29     1  1959598  1041  county         0.0  County Londonderry   23.0
# 30     4   335443  1041  county         0.0    County Roscommon  146.0
#
#     COUNT_area  sum_area_s  SHAPE_Leng  SHAPE_Area  \
# 0         12.0    1.640794    4.666724    0.364585
# 1        326.0   65.793049    4.655311    0.264633
# 2         31.0   46.945850    2.536513    0.148541
# 3         35.0   49.233812    6.072922    0.571557
# 4        186.0   16.549630   21.811325    0.980186
# 5         14.0    0.747029    4.777232    0.269099
# 6        183.0   84.083960    3.864349    0.218362
# 7        232.0  156.810236    4.233919    0.255713
# 8         27.0    2.169216    4.789672    0.244581
# 9          8.0    0.346849    3.267683    0.230039
# 10        13.0    4.890914    4.658227    0.314179
# 11       126.0   42.014039    6.402518    0.252516
# 12        13.0    0.426894    3.332604    0.274577
# 13       595.0  262.071887   22.678919    0.832528
# 14        32.0    5.939751    4.834269    0.318132
# 15       273.0   75.802370    6.407286    0.460028
# 16       269.0   19.213108    3.703796    0.178012
# 17        36.0    0.650717    4.138520    0.125474
# 18       149.0  111.555831    5.538343    0.453964
# 19         9.0    0.142486    3.049977    0.112977
# 20        12.0    0.605461    3.594766    0.227776
# 21        55.0   72.156503    3.538655    0.249128
# 22        65.0  203.524475    5.138240    0.433107
# 23       651.0   66.266910   20.914674    0.680704
# 24        30.0   25.578396    3.916034    0.270729
# 25        76.0   65.594069    2.813017    0.182935
# 26       145.0   60.121467   15.441098    0.630730
# 27        90.0   10.571922    7.612210    0.345254
# 28       420.0  210.249019   20.150238    0.765390
# 29        23.0   22.875568    3.807626    0.297241
# 30       146.0   89.011363    5.224706    0.346840
#
#                                              geometry
# 0   POLYGON ((475234.167 5824747.850, 475684.690 5...
# 1   POLYGON ((561384.726 6010212.270, 561384.663 6...
# 2   POLYGON ((563738.398 5942612.346, 563735.238 5...
# 3   POLYGON ((535072.881 5845408.127, 535245.110 5...
# 4   MULTIPOLYGON (((409772.431 5716469.862, 409787...
# 5   POLYGON ((561249.732 5891564.879, 561254.706 5...
# 6   POLYGON ((537132.204 6030522.394, 537188.592 6...
# 7   POLYGON ((553310.939 6035544.613, 553336.738 6...
# 8   MULTIPOLYGON (((557294.142 5777049.701, 557298...
# 9   POLYGON ((585203.930 5857273.288, 585829.802 5...
# 10  MULTIPOLYGON (((635172.987 5795794.421, 635210...
# 11  MULTIPOLYGON (((491084.748 6003309.671, 491089...
# 12  POLYGON ((589435.458 5848766.646, 589587.776 5...
# 13  MULTIPOLYGON (((413034.891 5940181.511, 413035...
# 14  POLYGON ((609092.576 5962437.594, 609867.094 5...
# 15  MULTIPOLYGON (((436361.293 5823701.959, 436384...
# 16  POLYGON ((608453.066 6001119.585, 608474.114 6...
# 17  MULTIPOLYGON (((663549.726 5906168.665, 663579...
# 18  POLYGON ((569548.679 6061493.983, 569591.098 6...
# 19  POLYGON ((651401.879 5975238.876, 651405.606 5...
# 20  POLYGON ((622356.808 5894407.506, 622511.834 5...
# 21  POLYGON ((568253.943 5919736.408, 568278.475 5...
# 22  MULTIPOLYGON (((648360.630 6119342.556, 648372...
# 23  MULTIPOLYGON (((510661.992 6057346.352, 510664...
# 24  MULTIPOLYGON (((648176.900 5873675.096, 648191...
# 25  POLYGON ((638151.068 6016668.475, 638167.028 6...
# 26  MULTIPOLYGON (((386057.299 5770776.555, 386063...
# 27  MULTIPOLYGON (((668775.482 6030395.233, 668774...
# 28  MULTIPOLYGON (((413449.430 5991853.507, 413451...
# 29  MULTIPOLYGON (((601961.616 6091904.380, 601974...
# 30  POLYGON ((511649.800 5946340.151, 511658.420 5...

# %%
counties
# Out:
#      osm_id  code  fclass  population         name  Field  \
# 0    334898  1041  county           0     Limerick    NaN
# 1   1959598  1041  county           0  Londonderry    NaN
# 2    335442  1041  county           0       Offaly    0.0
# 3    335445  1041  county           0     Longford    NaN
# 4    335443  1041  county           0    Roscommon    NaN
# 5    283426  1041  county           0    Waterford    NaN
# 6    334372  1041  county           0    Tipperary    NaN
# 7    283679  1041  county           0        Cavan    NaN
# 8    335330  1041  county           0        Sligo    NaN
# 9    284368  1041  county           0      Leitrim    NaN
# 10   332631  1041  county           0         Cork    NaN
# 11   285980  1041  county           0     Kilkenny    NaN
# 12   285915  1041  county           0        Laois    NaN
# 13  1118085  1041  county           0    Fermanagh    NaN
# 14   283647  1041  county           0     Monaghan    NaN
# 15   285977  1041  county           0       Carlow    NaN
# 16   285981  1041  county           0      Wexford    NaN
# 17  1117773  1041  county           0       Tyrone    NaN
# 18   334885  1041  county           0        Clare    NaN
# 19   335444  1041  county           0       Galway    NaN
# 20   335446  1041  county           0    Westmeath    NaN
# 21  1763195  1041  county           0        Louth    NaN
# 22   282818  1041  county           0        Meath    NaN
# 23   282760  1041  county           0      Wicklow    NaN
# 24   285833  1041  county           0      Kildare    NaN
# 25   282800  1041  county           0       Dublin    NaN
# 26  1119533  1041  county           0         Down    NaN
# 27  1119535  1041  county           0       Armagh    NaN
# 28  1119534  1041  county           0       Antrim    NaN
# 29  4085175  1041  county           0         Mayo    NaN
# 30   332622  1041  county           0        Kerry    NaN
# 31   283732  1041  county           0      Donegal    NaN
#
#                                              geometry
# 0   POLYGON ((475234.167 5824747.850, 475684.690 5...
# 1   MULTIPOLYGON (((601961.616 6091904.380, 601974...
# 2   POLYGON ((561249.732 5891564.879, 561254.706 5...
# 3   POLYGON ((563738.398 5942612.346, 563735.238 5...
# 4   POLYGON ((511649.800 5946340.151, 511658.420 5...
# 5   MULTIPOLYGON (((557294.142 5777049.701, 557298...
# 6   POLYGON ((535072.881 5845408.127, 535245.110 5...
# 7   POLYGON ((561384.726 6010212.270, 561384.663 6...
# 8   MULTIPOLYGON (((491084.748 6003309.671, 491089...
# 9   POLYGON ((537132.204 6030522.394, 537188.592 6...
# 10  MULTIPOLYGON (((409772.431 5716469.862, 409787...
# 11  POLYGON ((589435.458 5848766.646, 589587.776 5...
# 12  POLYGON ((585203.930 5857273.288, 585829.802 5...
# 13  POLYGON ((553310.939 6035544.613, 553336.738 6...
# 14  POLYGON ((608453.066 6001119.585, 608474.114 6...
# 15  POLYGON ((627774.931 5843388.087, 627775.006 5...
# 16  MULTIPOLYGON (((635172.987 5795794.421, 635210...
# 17  POLYGON ((569548.679 6061493.983, 569591.098 6...
# 18  MULTIPOLYGON (((436361.293 5823701.959, 436384...
# 19  MULTIPOLYGON (((413034.891 5940181.511, 413035...
# 20  POLYGON ((568253.943 5919736.408, 568278.475 5...
# 21  POLYGON ((651401.879 5975238.876, 651405.606 5...
# 22  POLYGON ((609092.576 5962437.594, 609867.094 5...
# 23  MULTIPOLYGON (((648176.900 5873675.096, 648191...
# 24  POLYGON ((622356.808 5894407.506, 622511.834 5...
# 25  MULTIPOLYGON (((663549.726 5906168.665, 663579...
# 26  MULTIPOLYGON (((668775.482 6030395.233, 668774...
# 27  POLYGON ((638151.068 6016668.475, 638167.028 6...
# 28  MULTIPOLYGON (((648360.630 6119342.556, 648372...
# 29  MULTIPOLYGON (((413449.430 5991853.507, 413451...
# 30  MULTIPOLYGON (((386057.299 5770776.555, 386063...
# 31  MULTIPOLYGON (((510661.992 6057346.352, 510664...

# %%
#shp_file = geopandas.read_file('myshpfile.shp')
#shp_file.to_file('myshpfile.geojson', driver='GeoJSON')

water = gpd.read_file('data_files/Files_for_analysis/water_per_county.shp')
#water = water.to_crs(epsg=2158)

#water.to_file('data_files/Files_for_analysis/county_water.geojson', driver='GeoJSON')

# %%
#county_water = gpd.read_file('data_files/Files_for_analysis/county_water.geojson')

#print (county_water.head())

# %%
fig, ax = plt.subplots(1, figsize=(12, 12))
# to make a nice colorbar that stays in line with our map, use these lines:
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1, axes_class=plt.Axes)

 
ax = water.plot(column='sum_area_s', ax=ax, vmin=0, vmax=275, cmap='bone_r', edgecolor='k',
                       legend=True, cax=cax, legend_kwds={'label': 'Total Area of Waterbodies in sq km'})
 
#Switch off the bounding box drawn round the map so it looks a bit tidier
ax.axis('off');

# %%
fig.savefig('Total area of inland water per county in ireland.png', dpi=300, bbox_inches='tight')
